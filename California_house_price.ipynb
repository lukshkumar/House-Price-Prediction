# %% [markdown]
# # Data Analysis on California House Pricing

# %%
print('Importing libraries')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('done')
# Out:
# Importing libraries
# done

# %%
print("importing dataset")

df = pd.read_csv('housing.csv')
df
# Out:
# importing dataset
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.total_bedrooms.count()
missing =  20640 - 20433
print('Missing values in total_ bedrooms: ', missing)

total_bedrooms_list = df.total_bedrooms.isnull().tolist()

print(type(total_bedrooms_list))

print(df.isnull().sum())

print(df.total_bedrooms.describe())
print(df.total_bedrooms.shape)
print("Visualizing the particular column")

x = range(1,20641)

fig = plt.gcf()

fig.set_size_inches(15,10)

plt.scatter(x,df.total_bedrooms)
# Out:
# Missing values in total_ bedrooms:  207
# <class 'list'>
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64
# (20640,)
# Visualizing the particular column

# %%
print(df.total_bedrooms.count())
df[df.total_bedrooms > 3000].count()
# Out:
# 20433
# longitude             67
# latitude              67
# housing_median_age    67
# total_rooms           67
# total_bedrooms        67
# population            67
# households            67
# median_income         67
# median_house_value    67
# ocean_proximity       67
# dtype: int64

# %%
sns.regplot(x = 'total_bedrooms', y ="median_house_value", data = df)

# %%
print("Box plot using pandas")

fig = plt.gcf()

fig.set_size_inches(15,10)
df.boxplot(column='total_bedrooms')
# Out:
# Box plot using pandas

# %%
iqr = 647 - 296 
max  = 6445 + (1.5*iqr)
print(max)
# Out:
# 6971.5

# %%
test = df[(df.total_bedrooms < 1000) | (df.total_bedrooms.isnull()) ]
hey = 20640 - 18757
print(hey)
print(df.shape)
print("test : ", test.shape)
print("Box plot using pandas")

fig = plt.gcf()

fig.set_size_inches(15,10)
test.boxplot(column='total_bedrooms')


print(test.total_bedrooms.describe())
test.isnull().sum()
# Out:
# 1883
# (20640, 10)
# test :  (18757, 10)
# Box plot using pandas
# count    18550.000000
# mean       437.627925
# std        211.589220
# min          1.000000
# 25%        284.000000
# 50%        408.000000
# 75%        572.000000
# max        999.000000
# Name: total_bedrooms, dtype: float64
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df[df['total_bedrooms'] >= 1000].count()
# Out:
# longitude             1883
# latitude              1883
# housing_median_age    1883
# total_rooms           1883
# total_bedrooms        1883
# population            1883
# households            1883
# median_income         1883
# median_house_value    1883
# ocean_proximity       1883
# dtype: int64

# %%
print("Converting the missing values into its mean")

df.total_bedrooms.replace(np.nan,test.total_bedrooms.mean(),inplace =True)
df.boxplot(column="total_bedrooms")
'''
df.total_bedrooms = df.total_bedrooms.astype(int)
index = 0
count =0

for x in df.total_bedrooms:
    if(df.total_bedrooms[index]>=1000):
        df.total_bedrooms.replace(df.total_bedrooms[index],test.total_bedrooms.mean(),inplace = True)
    index+=1
'''
# Out:
# Converting the missing values into its mean
# '\ndf.total_bedrooms = df.total_bedrooms.astype(int)\nindex = 0\ncount =0\n\nfor x in df.total_bedrooms:\n    if(df.total_bedrooms[index]>=1000):\n        df.total_bedrooms.replace(df.total_bedrooms[index],test.total_bedrooms.mean(),inplace = True)\n    index+=1\n'

# %%
df[df.total_bedrooms < 1000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# 11       -122.26     37.85                52.0       3503.0           752.0
# ...

# %%
df.total_bedrooms.isnull().sum()
# Out:
# 0

# %%
df.boxplot(column="total_bedrooms")
'''
test = df
fig = plt.gcf()
fig.set_size_inches(15,10)
#test.boxplot(column="total_bedrooms")

test.reset_index(drop = True, inplace = True)

index = 0
for x in test.total_bedrooms:
    if(test.total_bedrooms[index]>=880):
        test.total_bedrooms.replace(test.total_bedrooms[index],test.total_bedrooms.mean(),inplace = True)
    index+=1
    
test[test.total_bedrooms < 880].count()
test.boxplot(column="total_bedrooms")
'''
# Out:
# '\ntest = df\nfig = plt.gcf()\nfig.set_size_inches(15,10)\n#test.boxplot(column="total_bedrooms")\n\ntest.reset_index(drop = True, inplace = True)\n\nindex = 0\nfor x in test.total_bedrooms:\n    if(test.total_bedrooms[index]>=880):\n        test.total_bedrooms.replace(test.total_bedrooms[index],test.total_bedrooms.mean(),inplace = True)\n    index+=1\n    \ntest[test.total_bedrooms < 880].count()\ntest.boxplot(column="total_bedrooms")\n'

# %%
df.total_bedrooms.describe()
# Out:
# count    20640.000000
# mean       536.865212
# std        419.385560
# min          1.000000
# 25%        297.000000
# 50%        437.627925
# 75%        643.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
def outliers_iqr(data):
    first_quantile = data.quantile(.25)
    third_quantile = data.quantile(.75)
    iqr = third_quantile - first_quantile
    minimum = first_quantile -(1.5*iqr)
    maximum = third_quantile + (1.5*iqr)
    return df[(data >=minimum) & (data<=maximum)]
    
#Removing the outliers

df = outliers_iqr(df.total_bedrooms)
print(df.count())
df.boxplot(column = "total_bedrooms")
# Out:
# longitude             19334
# latitude              19334
# housing_median_age    19334
# total_rooms           19334
# total_bedrooms        19334
# population            19334
# households            19334
# median_income         19334
# median_house_value    19334
# ocean_proximity       19334
# dtype: int64

# %%
df = outliers_iqr(df.longitude)
print(df.count())
df.boxplot(column = "longitude")
# Out:
# longitude             19334
# latitude              19334
# housing_median_age    19334
# total_rooms           19334
# total_bedrooms        19334
# population            19334
# households            19334
# median_income         19334
# median_house_value    19334
# ocean_proximity       19334
# dtype: int64

# %%
df = outliers_iqr(df.latitude)
print(df.count())
df.boxplot(column = "latitude")
# Out:
# longitude             19334
# latitude              19334
# housing_median_age    19334
# total_rooms           19334
# total_bedrooms        19334
# population            19334
# households            19334
# median_income         19334
# median_house_value    19334
# ocean_proximity       19334
# dtype: int64

# %%
df = outliers_iqr(df.housing_median_age)
print(df.count())
df.boxplot(column = "housing_median_age")
# Out:
# longitude             19334
# latitude              19334
# housing_median_age    19334
# total_rooms           19334
# total_bedrooms        19334
# population            19334
# households            19334
# median_income         19334
# median_house_value    19334
# ocean_proximity       19334
# dtype: int64

# %%
df = outliers_iqr(df.total_rooms)
print(df.count())
df.boxplot(column = "total_rooms")
# Out:
# longitude             18762
# latitude              18762
# housing_median_age    18762
# total_rooms           18762
# total_bedrooms        18762
# population            18762
# households            18762
# median_income         18762
# median_house_value    18762
# ocean_proximity       18762
# dtype: int64

# %%
df = outliers_iqr(df.population)
print(df.count())
df.boxplot(column = "population")
# Out:
# longitude             18272
# latitude              18272
# housing_median_age    18272
# total_rooms           18272
# total_bedrooms        18272
# population            18272
# households            18272
# median_income         18272
# median_house_value    18272
# ocean_proximity       18272
# dtype: int64

# %%
df = outliers_iqr(df.households)
print(df.count())
df.boxplot(column = "households")
# Out:
# longitude             18022
# latitude              18022
# housing_median_age    18022
# total_rooms           18022
# total_bedrooms        18022
# population            18022
# households            18022
# median_income         18022
# median_house_value    18022
# ocean_proximity       18022
# dtype: int64

# %%
df = outliers_iqr(df.median_income)
print(df.count())
df.boxplot(column = "median_income")
# Out:
# longitude             17425
# latitude              17425
# housing_median_age    17425
# total_rooms           17425
# total_bedrooms        17425
# population            17425
# households            17425
# median_income         17425
# median_house_value    17425
# ocean_proximity       17425
# dtype: int64

# %%
df = outliers_iqr(df.median_house_value)
print(df.count())
df.boxplot(column = "median_house_value")
# Out:
# longitude             16778
# latitude              16778
# housing_median_age    16778
# total_rooms           16778
# total_bedrooms        16778
# population            16778
# households            16778
# median_income         16778
# median_house_value    16778
# ocean_proximity       16778
# dtype: int64

# %%
df.reset_index(drop =True, inplace = True)

# %% [markdown]
# # Outliers_removed DATA into CSV

# %%
df.to_csv('outliers_removed.csv')

# %%
df.rename(columns={'median_house_value' : 'price', 'housing_median_age' : 'lifetime'}, inplace = True)

# %%
df.corr()
# Out:
#                 longitude  latitude  lifetime  total_rooms  total_bedrooms  \
# longitude        1.000000 -0.922726 -0.082350    -0.013694        0.028222
# latitude        -0.922726  1.000000 -0.018685     0.014630       -0.039641
# lifetime        -0.082350 -0.018685  1.000000    -0.274729       -0.206143
# total_rooms     -0.013694  0.014630 -0.274729     1.000000        0.877120
# total_bedrooms   0.028222 -0.039641 -0.206143     0.877120        1.000000
# population       0.114022 -0.145120 -0.167484     0.755837        0.804654
# households       0.026649 -0.064573 -0.175189     0.874765        0.960356
# median_income   -0.003997 -0.089790 -0.167135     0.289180       -0.028057
# price           -0.036827 -0.165394  0.095298     0.191611        0.081033
#
#                 population  households  median_income     price
# longitude         0.114022    0.026649      -0.003997 -0.036827
# latitude         -0.145120   -0.064573      -0.089790 -0.165394
# ...

# %%
df.hist(bins = 50, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012054A6B550>,
# ...
#       dtype=object)

# %%
df.std()
# Out:
# longitude             2.004796
# latitude              2.173603
# lifetime             12.199536
# total_rooms         999.841750
# total_bedrooms      198.433189
# population          544.508715
# households          184.653442
# median_income         1.433105
# price             91233.673393
# dtype: float64

# %%
df = pd.read_csv('outliers_removed.csv')
df.drop('Unnamed: 0', axis = 1 , inplace =True)

# %%
df.rename(columns={'median_house_value' : 'price', 'housing_median_age' : 'lifetime'}, inplace = True)
df.hist(bins = 50, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001205574EEF0>,
# ...
#       dtype=object)

# %%
longitude  = df.longitude.mean() - df.longitude.std()
house =  df.households.mean() - df.households.std()
print(longitude, house)
# Out:
# -121.61780084750218 212.97315219249114

# %% [markdown]
# # Feature Selection using low Variance Method

# %%
'''
test = df.drop('ocean_proximity', axis = 1)
from sklearn.feature_selection import VarianceThreshold
var = VarianceThreshold(threshold = 15)
wow = var.fit_transform(test)
wow[0][5]
'''
# Out:
# "\ntest = df.drop('ocean_proximity', axis = 1)\nfrom sklearn.feature_selection import VarianceThreshold\nvar = VarianceThreshold(threshold = 15)\nwow = var.fit_transform(test)\nwow[0][5]\n"

# %%
test = df.drop('ocean_proximity', axis = 1)

from sklearn.feature_selection import mutual_info_regression
mutual_info_regression(test, test.price)
# Out:
# array([0.40589363, 0.37450773, 0.03346224, 0.03552642, 0.01946192,
#        0.01267901, 0.02437194, 0.31837531, 7.63934184])

# %%
df.ocean_proximity.unique()
sns.boxplot(x='ocean_proximity', y ='price', data = df)

# %%
group_data =  df[['ocean_proximity','price']].groupby('ocean_proximity')

mean =  group_data.mean()
print(mean)
group_data.count()
# Out:
#                          price
# ocean_proximity
# <1H OCEAN        215934.205035
# INLAND           118683.262232
# ISLAND           380440.000000
# NEAR BAY         225024.122563
# NEAR OCEAN       218771.855719
#                  price
# ocean_proximity
# <1H OCEAN         7189
# INLAND            5682
# ISLAND               5
# NEAR BAY          1795
# NEAR OCEAN        2107

# %%
df
# Out:
#        longitude  latitude  lifetime  total_rooms  total_bedrooms  population  \
# 0        -122.24     37.85      52.0       1467.0           190.0       496.0
# 1        -122.25     37.85      52.0       1274.0           235.0       558.0
# 2        -122.25     37.85      52.0       1627.0           280.0       565.0
# 3        -122.25     37.85      52.0        919.0           213.0       413.0
# 4        -122.25     37.84      52.0       2535.0           489.0      1094.0
# 5        -122.25     37.84      52.0       3104.0           687.0      1157.0
# 6        -122.26     37.84      42.0       2555.0           665.0      1206.0
# 7        -122.25     37.84      52.0       3549.0           707.0      1551.0
# 8        -122.26     37.85      52.0       2202.0           434.0       910.0
# 9        -122.26     37.85      52.0       3503.0           752.0      1504.0
# 10       -122.26     37.85      52.0       2491.0           474.0      1098.0
# ...

# %% [markdown]
# # Recursive Feature Elimination

# %%
X = df[['longitude','latitude','lifetime','total_rooms','total_bedrooms','population','households','median_income']]
Y = df[['price']]
# Recursive Feature Elimination
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
# load the iris datasets
#dataset = datasets.load_iris()
# create a base classifier used to evaluate a subset of attributes
model = LinearRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, 3)
rfe = rfe.fit(X,Y)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
print(rfe.score(X,Y))
# Out:
# [ True  True False False False False False  True]
# [1 1 2 6 3 5 4 1]
# 0.5408375677258626
# C:\Users\Luksh Kumar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Feature Importance
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
# load the iris datasets
# fit an Extra Trees model to the data
model = ExtraTreesClassifier()
model.fit(X, Y)
# display the relative importance of each attribute
print(model.feature_importances_)
# Out:
# C:\Users\Luksh Kumar\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# [0.12585365 0.12472049 0.11549758 0.127647   0.12532071 0.12699609
#  0.12505262 0.12891186]
